# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
#loading the data
df = pd.read_csv("Weather Data.csv")

# %%
#previewing the data
df
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %% [markdown]
# # **## DATA OVERVIEW AND CLEANING**

# %%
df.head(10) 
#This shows the top 10 rows of the dataset
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
# 2  1/1/2012 2:00    -1.8              -3.4         89                7
# 3  1/1/2012 3:00    -1.5              -3.2         88                6
# 4  1/1/2012 4:00    -1.5              -3.3         88                7
# 5  1/1/2012 5:00    -1.4              -3.3         87                9
# 6  1/1/2012 6:00    -1.5              -3.1         89                7
# 7  1/1/2012 7:00    -1.4              -3.6         85                7
# 8  1/1/2012 8:00    -1.4              -3.6         85                9
# 9  1/1/2012 9:00    -1.3              -3.1         88               15
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# ...

# %%
df.tail(10)
#This shows the bottom 10 rows of the data set
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 8774  12/31/2012 14:00    -3.4              -5.7         84                6
# 8775  12/31/2012 15:00    -2.3              -4.6         84                9
# 8776  12/31/2012 16:00    -1.4              -4.0         82               13
# 8777  12/31/2012 17:00    -1.1              -3.3         85               19
# 8778  12/31/2012 18:00    -1.3              -3.1         88               17
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
#       Visibility_km  Press_kPa Weather
# 8774           11.3     100.57    Snow
# 8775            9.7     100.47    Snow
# ...

# %%
#to check the number of rows and columns in the data set
df.shape
# Out:
# (8784, 8)

# %% [markdown]
# #there are 8784 rows and 8 columns

# %%
df.describe(include='all') 
#This shows the measures of cebtral tendancies such as mean, standard devaition, min etc including all null values.
# Out:
#             Date/Time       Temp_C  Dew Point Temp_C    Rel Hum_%  \
# count            8784  8784.000000       8784.000000  8784.000000
# unique           8784          NaN               NaN          NaN
# top     1/1/2012 0:00          NaN               NaN          NaN
# freq                1          NaN               NaN          NaN
# mean              NaN     8.798144          2.555294    67.431694
# std               NaN    11.687883         10.883072    16.918881
# min               NaN   -23.300000        -28.500000    18.000000
# 25%               NaN     0.100000         -5.900000    56.000000
# 50%               NaN     9.300000          3.300000    68.000000
# 75%               NaN    18.800000         11.800000    81.000000
# max               NaN    33.000000         24.400000   100.000000
#
#         Wind Speed_km/h  Visibility_km    Press_kPa       Weather
# count       8784.000000    8784.000000  8784.000000          8784
# ...

# %%
df.info()   #this shows the data tpes and non-null counts in each column within the data set
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date/Time         8784 non-null   object
#  1   Temp_C            8784 non-null   float64
#  2   Dew Point Temp_C  8784 non-null   float64
#  3   Rel Hum_%         8784 non-null   int64
#  4   Wind Speed_km/h   8784 non-null   int64
#  5   Visibility_km     8784 non-null   float64
#  6   Press_kPa         8784 non-null   float64
#  7   Weather           8784 non-null   object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 549.1+ KB

# %%
df.dtypes  # Checking the types of data in each column
# Out:
# Date/Time            object
# Temp_C              float64
# Dew Point Temp_C    float64
# Rel Hum_%             int64
# Wind Speed_km/h       int64
# Visibility_km       float64
# Press_kPa           float64
# Weather              object
# dtype: object

# %%
df.nunique()   #checking for the number of non-uniques values within the data in each column
# Out:
# Date/Time           8784
# Temp_C               533
# Dew Point Temp_C     489
# Rel Hum_%             83
# Wind Speed_km/h       34
# Visibility_km         24
# Press_kPa            518
# Weather               50
# dtype: int64

# %%
Weather_counts = df['Weather'].value_counts()
Weather_counts 
#Checking for the frequencies of the diffrent types of data variables in the weatehr column
# Out:
# Weather
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# ...

# %%
df['Wind Speed_km/h'].value_counts()         #to check for the frequencies of values in the wind speed_km/h column
# Out:
# Wind Speed_km/h
# 9     830
# 11    791
# 13    735
# 15    719
# 7     677
# 17    666
# 19    616
# 6     609
# 20    496
# 4     474
# 22    439
# 24    374
# 0     309
# 26    242
# 28    205
# 30    161
# 32    139
# 33     85
# 35     53
# 37     45
# 39     24
# 41     22
# 44     14
# 43     13
# 48     13
# 46     11
# 52      7
# 57      5
# 50      4
# 2       2
# 83      1
# 70      1
# 63      1
# 54      1
# Name: count, dtype: int64

# %%
#checking for null values
df.isna()
# Out:
#       Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0         False   False             False      False            False
# 1         False   False             False      False            False
# 2         False   False             False      False            False
# 3         False   False             False      False            False
# 4         False   False             False      False            False
# ...         ...     ...               ...        ...              ...
# 8779      False   False             False      False            False
# 8780      False   False             False      False            False
# 8781      False   False             False      False            False
# 8782      False   False             False      False            False
# 8783      False   False             False      False            False
#
#       Visibility_km  Press_kPa  Weather
# 0             False      False    False
# 1             False      False    False
# ...

# %%
df.isna().sum()      #to check for null values in  the dataset within the columns
# Out:
# Date/Time           0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# dtype: int64

# %%
df.isna().sum().sum()      #to check for null values in  the dataset
# Out:
# 0

# %% [markdown]
# #there are no null value hence no need for droping or filling values

# %%
#to check for any duplicates within the data set and key identifier which is the data/time column, the code returns values that are true 
df ['Date/Time'].duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8779    False
# 8780    False
# 8781    False
# 8782    False
# 8783    False
# Name: Date/Time, Length: 8784, dtype: bool

# %%
#to check duplicates and orders it by rows and get the number of times the duplicates appear
df ['Date/Time'].duplicated().sum().sum()
# Out:
# 0

# %% [markdown]
# There are no duplicates within the dataset
# our data is clean with no descreprancies of duplicates and null values.

# %%
#checking all the instances where the weather was 'exactly clear'
df[df['Weather'] == 'Clear']
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67      1/3/2012 19:00   -16.9             -24.8         50               24
# 114     1/5/2012 18:00    -7.1             -14.4         56               11
# 115     1/5/2012 19:00    -9.2             -15.4         61                7
# 116     1/5/2012 20:00    -9.8             -15.7         62                9
# 117     1/5/2012 21:00    -9.0             -14.8         63               13
# ...                ...     ...               ...        ...              ...
# 8646   12/26/2012 6:00   -13.4             -14.8         89                4
# 8698  12/28/2012 10:00    -6.1              -8.6         82               19
# 8713   12/29/2012 1:00   -11.9             -13.6         87               11
# 8714   12/29/2012 2:00   -11.8             -13.1         90               13
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
#       Visibility_km  Press_kPa Weather
# ...

# %%
#checking for the frequencies of where wind speed_km/h is 4
df[df['Wind Speed_km/h'] == 4].count()
# Out:
# Date/Time           474
# Temp_C              474
# Dew Point Temp_C    474
# Rel Hum_%           474
# Wind Speed_km/h     474
# Visibility_km       474
# Press_kPa           474
# Weather             474
# dtype: int64

# %%
df[df['Wind Speed_km/h'] == 4].count().sum()
# Out:
# 3792

# %%
df.rename(columns = {'Weather' : 'Weather_Condition'}, inplace=True)

# %%
df
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %%
#the mean value of visibility_km column
df['Visibility_km'].mean()
# Out:
# 27.664446721311478

# %%
#checking instances where wind speed is greater than 4, the 
df[df['Wind Speed_km/h'] > 4]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# 5        1/1/2012 5:00    -1.4              -3.3         87                9
# 6        1/1/2012 6:00    -1.5              -3.1         89                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %%
df[df['Wind Speed_km/h'] > 4].shape[0]  #shows the frequency of instances of wind speed greater than 4
# Out:
# 7999

# %%
#to check where the wind speed_km/h =25
df[df['Wind Speed_km/h'] == 25]
# Out:
# Empty DataFrame
# Columns: [Date/Time, Temp_C, Dew Point Temp_C, Rel Hum_%, Wind Speed_km/h, Visibility_km, Press_kPa, Weather_Condition]
# Index: []

# %%
df[df['Wind Speed_km/h'] == 25].shape[0]
# Out:
# 0

# %%
df.columns
# Out:
# Index(['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Rel Hum_%',
#        'Wind Speed_km/h', 'Visibility_km', 'Press_kPa', 'Weather_Condition'],
#       dtype='object')

# %%
#grouping the weather conditions and getting the mean of each weather condition temp_c
df.groupby ('Weather_Condition')['Temp_C'].mean()
# Out:
# Weather_Condition
# Clear                                       6.825716
# Cloudy                                      7.970544
# Drizzle                                     7.353659
# Drizzle,Fog                                 8.067500
# Drizzle,Ice Pellets,Fog                     0.400000
# Drizzle,Snow                                1.050000
# Drizzle,Snow,Fog                            0.693333
# Fog                                         4.303333
# Freezing Drizzle                           -5.657143
# Freezing Drizzle,Fog                       -2.533333
# Freezing Drizzle,Haze                      -5.433333
# Freezing Drizzle,Snow                      -5.109091
# Freezing Fog                               -7.575000
# Freezing Rain                              -3.885714
# Freezing Rain,Fog                          -2.225000
# Freezing Rain,Haze                         -4.900000
# Freezing Rain,Ice Pellets,Fog              -2.600000
# ...

# %%
df.groupby ('Weather_Condition')['Dew Point Temp_C'].mean()
# Out:
# Weather_Condition
# Clear                                       0.089367
# Cloudy                                      2.375810
# Drizzle                                     5.504878
# Drizzle,Fog                                 7.033750
# Drizzle,Ice Pellets,Fog                    -0.700000
# Drizzle,Snow                                0.150000
# Drizzle,Snow,Fog                            0.120000
# Fog                                         3.159333
# Freezing Drizzle                           -8.000000
# Freezing Drizzle,Fog                       -4.183333
# Freezing Drizzle,Haze                      -8.000000
# Freezing Drizzle,Snow                      -7.072727
# Freezing Fog                               -9.250000
# Freezing Rain                              -6.078571
# Freezing Rain,Fog                          -3.750000
# Freezing Rain,Haze                         -7.450000
# Freezing Rain,Ice Pellets,Fog              -3.700000
# ...

# %%
df.groupby ('Weather_Condition')['Rel Hum_%'].mean()
# Out:
# Weather_Condition
# Clear                                      64.497738
# Cloudy                                     69.592593
# Drizzle                                    88.243902
# Drizzle,Fog                                93.275000
# Drizzle,Ice Pellets,Fog                    92.000000
# Drizzle,Snow                               93.500000
# Drizzle,Snow,Fog                           95.866667
# Fog                                        92.286667
# Freezing Drizzle                           83.571429
# Freezing Drizzle,Fog                       88.500000
# Freezing Drizzle,Haze                      82.000000
# Freezing Drizzle,Snow                      86.090909
# Freezing Fog                               87.750000
# Freezing Rain                              84.642857
# Freezing Rain,Fog                          89.500000
# Freezing Rain,Haze                         82.500000
# Freezing Rain,Ice Pellets,Fog              92.000000
# ...

# %%
df.groupby ('Weather_Condition')['Wind Speed_km/h'].mean()
# Out:
# Weather_Condition
# Clear                                      10.557315
# Cloudy                                     16.127315
# Drizzle                                    16.097561
# Drizzle,Fog                                11.862500
# Drizzle,Ice Pellets,Fog                    20.000000
# Drizzle,Snow                               14.000000
# Drizzle,Snow,Fog                           15.533333
# Fog                                         7.946667
# Freezing Drizzle                           16.571429
# Freezing Drizzle,Fog                       17.000000
# Freezing Drizzle,Haze                      10.333333
# Freezing Drizzle,Snow                      16.272727
# Freezing Fog                                4.750000
# Freezing Rain                              19.214286
# Freezing Rain,Fog                          15.500000
# Freezing Rain,Haze                          7.500000
# Freezing Rain,Ice Pellets,Fog              28.000000
# ...

# %%
df.groupby ('Weather_Condition')['Visibility_km'].mean()
# Out:
# Weather_Condition
# Clear                                      30.153243
# Cloudy                                     26.625752
# Drizzle                                    17.931707
# Drizzle,Fog                                 5.257500
# Drizzle,Ice Pellets,Fog                     4.000000
# Drizzle,Snow                               10.500000
# Drizzle,Snow,Fog                            5.513333
# Fog                                         6.248000
# Freezing Drizzle                            9.200000
# Freezing Drizzle,Fog                        5.266667
# Freezing Drizzle,Haze                       2.666667
# Freezing Drizzle,Snow                       5.872727
# Freezing Fog                                0.650000
# Freezing Rain                               8.242857
# Freezing Rain,Fog                           7.550000
# Freezing Rain,Haze                          2.400000
# Freezing Rain,Ice Pellets,Fog               8.000000
# ...

# %%
df.groupby ('Weather_Condition')['Press_kPa'].mean()
# Out:
# Weather_Condition
# Clear                                      101.587443
# Cloudy                                     100.911441
# Drizzle                                    100.435366
# Drizzle,Fog                                100.786625
# Drizzle,Ice Pellets,Fog                    100.790000
# Drizzle,Snow                               100.890000
# Drizzle,Snow,Fog                            99.281333
# Fog                                        101.184067
# Freezing Drizzle                           100.202857
# Freezing Drizzle,Fog                       100.441667
# Freezing Drizzle,Haze                      100.316667
# Freezing Drizzle,Snow                      100.520909
# Freezing Fog                               102.320000
# Freezing Rain                               99.647143
# Freezing Rain,Fog                           99.945000
# Freezing Rain,Haze                         100.375000
# Freezing Rain,Ice Pellets,Fog              100.950000
# ...

# %%
df[df['Weather_Condition'] == 'Clear']
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67      1/3/2012 19:00   -16.9             -24.8         50               24
# 114     1/5/2012 18:00    -7.1             -14.4         56               11
# 115     1/5/2012 19:00    -9.2             -15.4         61                7
# 116     1/5/2012 20:00    -9.8             -15.7         62                9
# 117     1/5/2012 21:00    -9.0             -14.8         63               13
# ...                ...     ...               ...        ...              ...
# 8646   12/26/2012 6:00   -13.4             -14.8         89                4
# 8698  12/28/2012 10:00    -6.1              -8.6         82               19
# 8713   12/29/2012 1:00   -11.9             -13.6         87               11
# 8714   12/29/2012 2:00   -11.8             -13.1         90               13
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
# ...

# %%
df[df['Rel Hum_%'] >50]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %%
df[df['Visibility_km'] >40]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 106     1/5/2012 10:00    -6.0             -10.0         73               17
# 107     1/5/2012 11:00    -5.6             -10.2         70               22
# 108     1/5/2012 12:00    -4.7              -9.6         69               20
# 109     1/5/2012 13:00    -4.4              -9.7         66               26
# 110     1/5/2012 14:00    -5.1             -10.7         65               22
# ...                ...     ...               ...        ...              ...
# 8748  12/30/2012 12:00   -12.2             -15.7         75               26
# 8749  12/30/2012 13:00   -12.4             -16.2         73               37
# 8750  12/30/2012 14:00   -11.8             -16.1         70               37
# 8751  12/30/2012 15:00   -11.3             -15.6         70               32
# 8752  12/30/2012 16:00   -11.4             -15.5         72               26
#
# ...

# %%
#Show all instances where the weather condition contains snow
df[df['Weather_Condition'].str.contains ('Snow')]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 41      1/2/2012 17:00    -2.1              -9.5         57               22
# 44      1/2/2012 20:00    -5.6             -13.4         54               24
# 45      1/2/2012 21:00    -5.8             -12.8         58               26
# 47      1/2/2012 23:00    -7.4             -14.1         59               17
# 48       1/3/2012 0:00    -9.0             -16.0         57               28
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %% [markdown]
# **## # STATISTICAL SUMMARY**

# %%
#this shows measures of central tendancies of the each column including standard deviation, mean, maximum and minimum values for all the values even string data types
df.describe (include ='all')
# Out:
#             Date/Time       Temp_C  Dew Point Temp_C    Rel Hum_%  \
# count            8784  8784.000000       8784.000000  8784.000000
# unique           8784          NaN               NaN          NaN
# top     1/1/2012 0:00          NaN               NaN          NaN
# freq                1          NaN               NaN          NaN
# mean              NaN     8.798144          2.555294    67.431694
# std               NaN    11.687883         10.883072    16.918881
# min               NaN   -23.300000        -28.500000    18.000000
# 25%               NaN     0.100000         -5.900000    56.000000
# 50%               NaN     9.300000          3.300000    68.000000
# 75%               NaN    18.800000         11.800000    81.000000
# max               NaN    33.000000         24.400000   100.000000
#
#         Wind Speed_km/h  Visibility_km    Press_kPa Weather_Condition
# count       8784.000000    8784.000000  8784.000000              8784
# ...

# %%
#this now excluded all data types that are string all null values
df.describe()
# Out:
#             Temp_C  Dew Point Temp_C    Rel Hum_%  Wind Speed_km/h  \
# count  8784.000000       8784.000000  8784.000000      8784.000000
# mean      8.798144          2.555294    67.431694        14.945469
# std      11.687883         10.883072    16.918881         8.688696
# min     -23.300000        -28.500000    18.000000         0.000000
# 25%       0.100000         -5.900000    56.000000         9.000000
# 50%       9.300000          3.300000    68.000000        13.000000
# 75%      18.800000         11.800000    81.000000        20.000000
# max      33.000000         24.400000   100.000000        83.000000
#
#        Visibility_km    Press_kPa
# count    8784.000000  8784.000000
# mean       27.664447   101.051623
# std        12.622688     0.844005
# min         0.200000    97.520000
# 25%        24.100000   100.560000
# 50%        25.000000   101.070000
# 75%        25.000000   101.590000
# max        48.300000   103.650000

# %%
#for statistical and numerical computation numpy is used
df.mode()
# Out:
#            Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0      1/1/2012 0:00    16.6              -0.9       68.0              9.0
# 1     1/1/2012 10:00     NaN              12.9        NaN              NaN
# 2     1/1/2012 11:00     NaN               NaN        NaN              NaN
# 3     1/1/2012 12:00     NaN               NaN        NaN              NaN
# 4     1/1/2012 13:00     NaN               NaN        NaN              NaN
# ...              ...     ...               ...        ...              ...
# 8779   9/9/2012 5:00     NaN               NaN        NaN              NaN
# 8780   9/9/2012 6:00     NaN               NaN        NaN              NaN
# 8781   9/9/2012 7:00     NaN               NaN        NaN              NaN
# 8782   9/9/2012 8:00     NaN               NaN        NaN              NaN
# 8783   9/9/2012 9:00     NaN               NaN        NaN              NaN
#
#       Visibility_km  Press_kPa Weather_Condition
# ...

# %%
#to find a calculation eg mean of a specific column
df['Visibility_km'].mean()
# Out:
# 27.664446721311478

# %%
df['Visibility_km'].mode()
# Out:
# 0    25.0
# Name: Visibility_km, dtype: float64

# %%
df['Temp_C'].median()
# Out:
# 9.3

# %%
#to identify outliers
#checking for outliers in the 'Visibility_km' column
Q1= df['Visibility_km'].quantile(0.25)
Q3= df['Visibility_km'].quantile(0.75)
IQR= Q3-Q1
print (IQR)
# Out:
# 0.8999999999999986

# %%
threshold = 0.8999999999999986

Outliers = df[(df['Visibility_km'] < Q1 - threshold * IQR) | (df['Visibility_km'] > Q3 + threshold * IQR)]
print(Outliers)
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %% [markdown]
# ## **Data Visualization**

# %%
#we can identify outliers by using boxplots
sns.boxplot(x ='Temp_C', y = 'Wind Speed_km/h', data = df)
# Out:
# <Axes: xlabel='Temp_C', ylabel='Wind Speed_km/h'>

# %%
sns.regplot (x='Temp_C', y= 'Wind Speed_km/h', data=df )
# Out:
# <Axes: xlabel='Temp_C', ylabel='Wind Speed_km/h'>

# %%
sns.boxplot(x ='Wind Speed_km/h', y = 'Press_kPa', data = df)
# Out:
# <Axes: xlabel='Wind Speed_km/h', ylabel='Press_kPa'>

# %%
sns.regplot (x='Wind Speed_km/h', y= 'Press_kPa', data=df )
# Out:
# <Axes: xlabel='Wind Speed_km/h', ylabel='Press_kPa'>

# %%
#there is a relation between Wind Speed and pressure where when wind speed increases the pressure decreases

# %%
sns.regplot (x='Visibility_km', y= 'Wind Speed_km/h', data=df )
# Out:
# <Axes: xlabel='Visibility_km', ylabel='Wind Speed_km/h'>

# %%
#there is no corelation between the visibility and wind speed

# %%
df.columns
# Out:
# Index(['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Rel Hum_%',
#        'Wind Speed_km/h', 'Visibility_km', 'Press_kPa', 'Weather_Condition'],
#       dtype='object')

# %%
sns.regplot (x='Rel Hum_%', y= "Temp_C",  data=df )
# Out:
# <Axes: xlabel='Rel Hum_%', ylabel='Temp_C'>

# %%
df_1=df[["Wind Speed_km/h", "Press_kPa"]]
df_1
df_1.head(10)
# Out:
#    Wind Speed_km/h  Press_kPa
# 0                4     101.24
# 1                4     101.24
# 2                7     101.26
# 3                6     101.27
# 4                7     101.23
# 5                9     101.27
# 6                7     101.29
# 7                7     101.26
# 8                9     101.23
# 9               15     101.20

# %%
df_1grp = df_1.groupby(["Wind Speed_km/h"], as_index = False).sum()
df_1grp
# Out:
#     Wind Speed_km/h  Press_kPa
# 0                 0   31312.62
# 1                 2     205.22
# 2                 4   48081.93
# 3                 6   61739.49
# 4                 7   68585.44
# 5                 9   84047.19
# 6                11   80038.80
# 7                13   74359.79
# 8                15   72666.08
# 9                17   67255.11
# 10               19   62160.40
# 11               20   50066.57
# 12               22   44257.06
# 13               24   37696.52
# 14               26   24372.22
# 15               28   20625.27
# 16               30   16197.21
# 17               32   13968.84
# 18               33    8517.52
# 19               35    5310.27
# 20               37    4508.45
# 21               39    2400.32
# 22               41    2191.98
# 23               43    1298.11
# 24               44    1400.12
# 25               46    1092.91
# 26               48    1296.20
# 27               50     396.71
# 28               52     698.72
# ...

# %%
df[["Visibility_km"]].value_counts()
# Out:
# Visibility_km
# 25.0             3324
# 48.3             2014
# 24.1             1921
# 19.3              281
# 16.1              224
# 9.7               181
# 12.9              174
# 6.4               129
# 8.0               122
# 4.8                79
# 4.0                55
# 2.4                50
# 3.2                42
# 11.3               36
# 2.0                28
# 1.2                28
# 1.6                25
# 0.6                16
# 2.8                15
# 3.6                11
# 1.0                11
# 0.2                 8
# 0.8                 7
# 0.4                 3
# Name: count, dtype: int64

# %%
df_test = df[["Wind Speed_km/h", "Visibility_km", "Press_kPa"]]
df_test
# Out:
#       Wind Speed_km/h  Visibility_km  Press_kPa
# 0                   4            8.0     101.24
# 1                   4            8.0     101.24
# 2                   7            4.0     101.26
# 3                   6            4.0     101.27
# 4                   7            4.8     101.23
# ...               ...            ...        ...
# 8779               30            9.7     100.13
# 8780               24            9.7     100.03
# 8781               28            4.8      99.95
# 8782               28            9.7      99.91
# 8783               30           11.3      99.89
#
# [8784 rows x 3 columns]

# %%
df_grp = df_test.groupby(["Wind Speed_km/h", "Press_kPa"], as_index = False).mean()
df_grp
# Out:
#       Wind Speed_km/h  Press_kPa  Visibility_km
# 0                   0      99.14           25.0
# 1                   0      99.32           25.0
# 2                   0      99.39           25.0
# 3                   0      99.40           25.0
# 4                   0      99.75           25.0
# ...               ...        ...            ...
# 4094               57      99.07           25.0
# 4095               57      99.96           25.0
# 4096               63      98.67           48.3
# 4097               70      98.62           25.0
# 4098               83      98.36           25.0
#
# [4099 rows x 3 columns]

# %%
df_pivot = df_grp.pivot(index = "Wind Speed_km/h", columns = "Press_kPa")
df_pivot
# Out:
#                 Visibility_km                                            \
# Press_kPa              97.52  97.56  97.58  97.64  97.75  97.76  97.79
# Wind Speed_km/h
# 0                         NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2                         NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 4                         NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 6                         NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 7                         NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 9                         NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 11                        NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 13                        NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 15                        NaN    NaN    9.7    NaN    NaN    NaN    NaN
# 17                        NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 19                        NaN    NaN    NaN    NaN    NaN    NaN    NaN
# ...

# %%
sns.regplot (x='Wind Speed_km/h', y= 'Press_kPa', data=df )
# Out:
# <Axes: xlabel='Wind Speed_km/h', ylabel='Press_kPa'>

# %%
df_numeric = df.select_dtypes(include=[float, int])
corr_matrix = df_numeric.corr()
corr_matrix
# Out:
#                     Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# Temp_C            1.000000          0.932714  -0.220182        -0.061876
# Dew Point Temp_C  0.932714          1.000000   0.139494        -0.095685
# Rel Hum_%        -0.220182          0.139494   1.000000        -0.092743
# Wind Speed_km/h  -0.061876         -0.095685  -0.092743         1.000000
# Visibility_km     0.273455          0.050813  -0.633683         0.004883
# Press_kPa        -0.236389         -0.320616  -0.231424        -0.356613
#
#                   Visibility_km  Press_kPa
# Temp_C                 0.273455  -0.236389
# Dew Point Temp_C       0.050813  -0.320616
# Rel Hum_%             -0.633683  -0.231424
# Wind Speed_km/h        0.004883  -0.356613
# Visibility_km          1.000000   0.231847
# Press_kPa              0.231847   1.000000

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()
